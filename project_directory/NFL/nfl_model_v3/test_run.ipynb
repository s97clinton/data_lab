# %%
from functions.import_scripts import run_nfl_data_import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from functions.import_scripts import run_nfl_data_import
#
# File ~/Documents/_sjc_repo_/data_lab/project_directory/NFL/nfl_model_v3/functions/import_scripts.py:3
#       1 import os
#       2 import pandas as pd
# ----> 3 from functions.utils import create_nfl_engine
#       5 def import_schedule_csv(season):
#       6     """
#       7     Function:
#       8     -Imports the NFL schedule with the games to be projected
#    (...)     17     <df> (Pandas Dataframe): Pandas Dataframe w/ NFL schedule data
#      18     """
#
# File ~/Documents/_sjc_repo_/data_lab/project_directory/NFL/nfl_model_v3/functions/utils.py:2
#       1 from sqlalchemy import create_engine
# ----> 2 from functions.credentials import MYSQL_USER, MYSQL_PASSWORD
#       4 def create_nfl_engine(user = MYSQL_USER, password = MYSQL_PASSWORD, host = 'localhost', port = 3306, database = 'nfl'):
#       5     connection_string = f"mysql+pymysql://{user}:{password}@{host}:{port}/{database}"
#
# ModuleNotFoundError: No module named 'functions.credentials'

# %%
nfl_schedule, hist_rating_df, coach_qb_df,  pfr_game_basic, pfr_team_stats, pfr_pass_df, pfr_rush_df, pfr_rec_df, pfr_drive_df = run_nfl_data_import(start_season, current_season)
