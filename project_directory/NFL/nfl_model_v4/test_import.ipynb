# %%
import nfl_data_py as nfl
from functions.data_transformation import prep_nfl_data_py_pbp, filter_and_subset_nfl_data_py_pbp, nfl_data_py_pbp_to_drives
from functions.feature_engineering import create_features_nfl_data_py

# %%
# seasons = [2024, 2025]
# df = nfl.import_pbp_data(years = seasons)
# base_df = prep_nfl_data_py_pbp(df)
# pbp_df = filter_and_subset_nfl_data_py_pbp(base_df)
# pbp_df = create_features_nfl_data_py(pbp_df)
# pbp_df.to_csv("csv_output/check_pbp.csv", index=False)
# drive_df = nfl_data_py_pbp_to_drives(base_df)
# drive_df.to_csv("csv_output/check_drive.csv")
# Out:
# 2024 done.
# 2025 done.
# Downcasting floats.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## TO DO LIST ON IMPORT
#
# 1. Create "Weekly" Level Training Set
