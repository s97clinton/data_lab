# %%
from functions.import_data_parquet import NFLDataLoader

# %%
training_set_seasons = [2023, 2024]

# %%
nfl_data_loader = NFLDataLoader()
pbp_import_df = nfl_data_loader.pbp(seasons = training_set_seasons)
schedule_import_df = nfl_data_loader.schedule(seasons = training_set_seasons)

# %%
pbp_import_df
# Out:
#        play_id          game_id old_game_id_x home_team away_team season_type  \
# 0          1.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 1         39.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 2         55.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 3         77.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# 4        102.0  2023_01_ARI_WAS    2023091007       WAS       ARI         REG
# ...        ...              ...           ...       ...       ...         ...
# 99152   4158.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99153   4181.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99154   4203.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99155   4225.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
# 99156   4247.0   2024_22_KC_PHI    2025020900       PHI        KC        POST
#
# ...
