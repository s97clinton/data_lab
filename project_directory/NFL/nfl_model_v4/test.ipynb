# %%
from functions.import_data_parquet import import_nfl_data_py_pbp_parquet

# %%
seasons = [2021, 2022, 2023]

# %%
df = import_nfl_data_py_pbp_parquet(seasons)

# %%
df
# Out:
#         play_id          game_id  ...                 defense_numbers old_game_id
# 142074      1.0  2021_01_ARI_TEN  ...                            None        None
# 142075     40.0  2021_01_ARI_TEN  ...                            None        None
# 142076     55.0  2021_01_ARI_TEN  ...                            None        None
# 142077     76.0  2021_01_ARI_TEN  ...                            None        None
# 142078    100.0  2021_01_ARI_TEN  ...                            None        None
# ...         ...              ...  ...                             ...         ...
# 291090   4791.0    2023_22_SF_KC  ...  7;2;97;92;91;90;31;33;54;48;27        None
# 291091   4813.0    2023_22_SF_KC  ...  7;2;97;92;91;90;31;33;54;48;27        None
# 291092   4835.0    2023_22_SF_KC  ...  7;2;97;92;98;99;31;33;54;48;27        None
# 291093   4860.0    2023_22_SF_KC  ...  7;2;97;92;98;99;31;33;54;48;27        None
# ...
