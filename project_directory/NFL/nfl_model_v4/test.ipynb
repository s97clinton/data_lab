# %%
import nfl_data_py as nfl
from functions.data_transformation import prep_schedule_data, convert_schedule_to_test_frame

# %%
df = nfl.import_schedules([2023, 2024, 2025])

# %%
df = prep_schedule_data(df)

# %%
df = convert_schedule_to_test_frame(df, 2025, 9)

# %%
df
# Out:
#      season  week          game_id     gameday gametime  neutral_site offense  \
# 0      2025    10   2025_10_LV_DEN  2025-11-06    20:15         False      LV
# 1      2025    10  2025_10_ATL_IND  2025-11-09    09:30          True     ATL
# 2      2025    10   2025_10_NO_CAR  2025-11-09    13:00         False      NO
# 3      2025    10  2025_10_NYG_CHI  2025-11-09    13:00         False     NYG
# 4      2025    10  2025_10_JAX_HOU  2025-11-09    13:00         False     JAX
# ..      ...   ...              ...         ...      ...           ...     ...
# 269    2025    18  2025_18_DAL_NYG  2026-01-04    13:00         False     NYG
# 270    2025    18  2025_18_WAS_PHI  2026-01-04    13:00         False     PHI
# 271    2025    18  2025_18_BAL_PIT  2026-01-04    13:00         False     PIT
# 272    2025    18   2025_18_SEA_SF  2026-01-04    13:00         False      SF
# 273    2025    18   2025_18_CAR_TB  2026-01-04    13:00         False      TB
#
# ...
