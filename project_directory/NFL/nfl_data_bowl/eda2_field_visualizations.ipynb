# %%
from nfl_data_bowl_functions.data_imports import import_single_nfl_week_input, import_all_nfl_weeks_input
from nfl_data_bowl_functions.field_visualizations import *

# %%
input_df = import_single_nfl_week_input(2023, 1, merge_supplementary=False)
# full_input_df = import_all_nfl_weeks_input(merge_supplementary=False)
# Out:
# ✓ 2023 Week 1 data: 285,714 play frames loaded

# %%
visualize_overall_density(input_df)

# %%
visualize_speed_zone(input_df, quantile=0.5)

# %%
visualize_acceleration_zone(input_df, quantile=0.5)

# %%
visualize_player_role(input_df, role='Passer')

# %%
visualize_position_heatmap(input_df, position='WR')

# %%
visualize_ball_landing_zones(input_df)

# %%
visualize_direction_movement(input_df, dir_min=0, dir_max=360)

# %%
visualize_player_side(input_df, side='Offense')

# %%
visualize_early_frames(input_df)
